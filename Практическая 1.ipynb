# %%
#Задача 3
father_age = 20
son_age = 3
result = (father_age - son_age) / (1 - 0.5) - son_age
result = (father_age - 2 * son_age) / (2-1)
print("Задача 3:", result)
# Out:
# Задача 3: 14.0

# %%
#Задача 4
a, b, c = 3, 4, 5
perimeter = a + b + c
p = perimeter / 2
area = (p * (p - a) * (p - b) * (p - c)) ** 0.5
print("Задача 4:", "Периметр =", perimeter, "Площадь = ", area)
# Out:
# Задача 4: Периметр = 12 Площадь =  6.0

# %%
#Задача 5 
n = 23810
hours = n // 3600
minutes = (n % 3600) // 60 
seconds = n % 60
print("Задача 5:", "Часы =", hours, "Минуты = ", minutes, "Секунды = ", seconds)
# Out:
# Задача 5: Часы = 6 Минуты =  36 Секунды =  50

# %%
#Задача 6 
price_new = 89.99
price_old = 75.50
result = round(abs(price_new - price_old) / price_old * 100, 2)
print("Задача 6:", "Результат - ", result)
# Out:
# Задача 6: Результат -  19.19

# %%
#Задача 7
a = 5 #Тип int
b = "10" #Тип str
c = True #Тип bool
my_sum = a + int(b) + int(c)
print("Задача 7:", "Результат - ", my_sum)
# Out:
# Задача 7: Результат -  16

# %%
#Задача 8 
a = '3.14'
c = int(float(a))
print("Задача 8:", "Результат - ", c)
# Out:
# Задача 8: Результат -  3

# %%
#Задача 9
x = 2
result = x + int(str(x) + '0' + str(x) + '0' + str(x))
print("Задача 9:", "Результат - ", result)
# Out:
# Задача 9: Результат -  20204

# %%
#Задача 10 
print("Задача 10:")
print("'ИВАН' < 'иван' =", 'ИВАН' < 'иван')
print("'Python' < 'R' =", 'Python' < 'R')
print("'big number' < 'bug number' =", 'big number' != 'bug number')
print("'ЯЯЯ' == 'Я Я' =", 'ЯЯЯ' == 'Я Я')
print("'игра' == 'икра' =", 'игра' >= 'икра')
# Out:
# Задача 10:
# 'ИВАН' < 'иван' = True
# 'Python' < 'R' = True
# 'big number' < 'bug number' = True
# 'ЯЯЯ' == 'Я Я' = False
# 'игра' == 'икра' = False

# %%
#Задача 11
m = 500
optimal_sleep_duration = 7 <= m / 60 <= 9
print("Задача 11:", "Результат - ", optimal_sleep_duration)
# Out:
# Задача 11: Результат -  True

# %%
#Задача 12
x = 21
result = x % 3 == 0 and x % 7 == 0 
print("Задача 12:", "Результат - ", result)
# Out:
# Задача 12: Результат -  True

# %%
#Задача 13
a = False - True
b = True + 0
c = bool(False + 1)
d = True + 0.1
e = True ** 0.5
f = False ** True
g = 2 == True

print("a =", a)   # -1
print("b =", b)   # 1
print("c =", c)   # True
print("d =", d)   # 1.1
print("e =", e)   # 1.0
print("f =", f)   # 0
print("g =", g)   # False
# Out:
# a = -1
# b = 1
# c = True
# d = 1.1
# e = 1.0
# f = 0
# g = False

# %%
#Задача 14
square = "\n".join(["* * * *" for _ in range(4)])  
print("Задача 14:")
print(square)
# Out:
# Задача 14:
# * * * *
# * * * *
# * * * *
# * * * *
